# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
tors = pd.read_csv('./1950-2018_actual_tornadoes.csv')

# %%
tors0918 = tors[(tors['yr'] > 2008) & (tors['mag'] > -1)]

# %%
tors0918
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 52080       1  2009   1   3  2009-01-03  13:13:00   3  MS   28    0  ...
# 52081       2  2009   1   6  2009-01-06  16:05:00   3  GA   13    0  ...
# 52082       3  2009   1   7  2009-01-07  02:00:00   3  GA   13    0  ...
# 52083       4  2009   1  10  2009-01-10  15:33:00   3  MS   28    0  ...
# 52084       5  2009   1  10  2009-01-10  17:05:00   3  AL    1    0  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 63640  617020  2018  12  27  2018-12-27  10:15:00   3  LA   22    0  ...
# 63641  617021  2018  12  27  2018-12-27  10:29:00   3  MS   28    0  ...
# 63642  617022  2018  12  31  2018-12-31  12:35:00   3  KY   21    0  ...
# 63643  617023  2018  12  31  2018-12-31  13:43:00   3  IN   18    0  ...
# 63644  617024  2018  12  31  2018-12-31  14:38:00   3  IN   18    0  ...
#
#         len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# ...

# %%
sns.distplot(tors0918['mag'],kde=True,rug=False,bins=np.arange(0,7),kde_kws={'clip':(0,6),'gridsize':6,'bw':0.5})
# Out:
# <AxesSubplot:xlabel='mag'>

# %%
apr27 = tors[tors['date'] == '2011-04-27']

# %%
sns.distplot(apr27['mag'],kde=True,rug=False,bins=np.arange(0,7),kde_kws={'clip':(0,6),'gridsize':6,'bw':0.5})
# Out:
# <AxesSubplot:xlabel='mag'>

# %%
np.min(apr27['mag'])
# Out:
# 0

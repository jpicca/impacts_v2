# %%
import pandas as pd
import numpy as np
import glob

# %%
df = pd.read_csv('./test_data/199906011630_pp.psv.gz',sep='|',nrows=50)

# %%
#df.loc[:50,'counties'].apply(lambda x: len(x.split(','))).mean()
df['counties'].apply(lambda x: len(x.split(','))).mean()
# Out:
# 12.22

# %%
filepath = '/Volumes/Backup Plus/pas_output/simulationFiles/*'
paths = glob.glob(filepath)

# %%
naughtyList = []

for path in paths:
    df = pd.read_csv(path,sep='|',nrows=50)
    
    cos_impacted = df['counties'].apply(lambda x: len(str(x).split(','))).mean()
    
    if cos_impacted > 2:
        print('Uh oh!')
        naughtyList.append(path)
# Out:
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# Uh oh!
# ...

# %%
len(naughtyList)
# Out:
# 309

# %%
# Out:
#     sim  population  distance  rating    states  \
# 0     1       36784    0.8324       0        LA
# 1     2        1200    1.3466       3        LA
# 2     2        2512    0.2762       0        LA
# 3     3           0    3.9809       1        LA
# 4     4        3520    1.4473       0        LA
# 5     4           0    1.0626       0       NaN
# 6     4       47056    0.0933       0        LA
# 7     4       33216    1.4835       1  AL,LA,MS
# 8     4       13936    0.1226       0        LA
# 9     4       44496    2.4136       1        LA
# 10    4         624    2.6381       1        LA
# 11    4           0    1.3579       0       NaN
# 12    4           0    0.7180       1       NaN
# 13    4           0    0.8976       2       NaN
# 14    4           0    1.4309       1       NaN
# 15    4      218144    6.7925       1     LA,MS
# 16    4       24496    0.8586       1        LA
# 17    5      120800    0.6244       0        LA
# ...
